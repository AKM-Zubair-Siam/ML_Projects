# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV, train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from scipy.stats import uniform, randint
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix 
from sklearn import svm
# Out:
# C:\Users\Zooby\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data['Unnamed: 32'].value_counts()
# Out:
# Series([], Name: Unnamed: 32, dtype: int64)

# %%
data.shape
# Out:
# (569, 33)

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit label encoder and return encoded labels
data['diagnosis'] = label_encoder.fit_transform(data['diagnosis'])

# %%
data['diagnosis'].value_counts() # 0 means no breast cancer. 1 means breast cancer
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# Splitting features and label

# %%
X = data.drop(columns = ['id', 'Unnamed: 32', 'diagnosis'])
Y = data['diagnosis']

# %% [markdown]
# standardizing data

# %%
scaler = StandardScaler()
standardized_data = scaler.fit_transform(X)
print(standardized_data)
# Out:
# [[ 1.09706398 -2.07333501  1.26993369 ...  2.29607613  2.75062224
#    1.93701461]
#  [ 1.82982061 -0.35363241  1.68595471 ...  1.0870843  -0.24388967
#    0.28118999]
#  [ 1.57988811  0.45618695  1.56650313 ...  1.95500035  1.152255
#    0.20139121]
#  ...
#  [ 0.70228425  2.0455738   0.67267578 ...  0.41406869 -1.10454895
#   -0.31840916]
#  [ 1.83834103  2.33645719  1.98252415 ...  2.28998549  1.91908301
#    2.21963528]
#  [-1.80840125  1.22179204 -1.81438851 ... -1.74506282 -0.04813821
#   -0.75120669]]

# %%
X = standardized_data
Y = data['diagnosis']
print(X,Y)
# Out:
# [[ 1.09706398 -2.07333501  1.26993369 ...  2.29607613  2.75062224
#    1.93701461]
#  [ 1.82982061 -0.35363241  1.68595471 ...  1.0870843  -0.24388967
#    0.28118999]
#  [ 1.57988811  0.45618695  1.56650313 ...  1.95500035  1.152255
#    0.20139121]
#  ...
#  [ 0.70228425  2.0455738   0.67267578 ...  0.41406869 -1.10454895
#   -0.31840916]
#  [ 1.83834103  2.33645719  1.98252415 ...  2.28998549  1.91908301
#    2.21963528]
#  [-1.80840125  1.22179204 -1.81438851 ... -1.74506282 -0.04813821
#   -0.75120669]] 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int32

# %% [markdown]
# train test split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = .2, stratify = Y)

# %% [markdown]
# #model creation

# %%
logistic_param_grid = {
    'penalty': ['l1', 'l2'],
    'C': np.logspace(-6, 6, 13),
    'solver': ['liblinear', 'saga']
}

xgboost_param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    'subsample': [0.5, 0.8, 1.0],
    'colsample_bytree': [0.5, 0.8, 1.0]
}

svm_param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [0.01, 0.1, 1, 'scale', 'auto'],
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid']
}

# RandomizedSearchCV for each model
logistic_random_search = RandomizedSearchCV(LogisticRegression(), logistic_param_grid, n_iter=100, cv=5, n_jobs=-1)
xgboost_random_search = RandomizedSearchCV(XGBClassifier(probability=False), xgboost_param_grid, n_iter=100, cv=5, n_jobs=-1)
svm_random_search = RandomizedSearchCV(svm.SVC(), svm_param_grid, n_iter=100, cv=5, n_jobs=-1)

# Fit models using RandomizedSearchCV
logistic_random_search.fit(X_train, Y_train)
xgboost_random_search.fit(X_train, Y_train)
svm_random_search.fit(X_train, Y_train)

# Print best hyperparameters from RandomizedSearchCV
print("Logistic Regression Best Parameters:", logistic_random_search.best_params_)
print("XGBoost Best Parameters:", xgboost_random_search.best_params_)
print("SVM Best Parameters:", svm_random_search.best_params_)

# GridSearchCV for each model using the full hyperparameter grid
logistic_grid_search = GridSearchCV(LogisticRegression(), param_grid=logistic_param_grid, cv=5, n_jobs=-1)
xgboost_grid_search = GridSearchCV(XGBClassifier(probability=False), param_grid=xgboost_param_grid, cv=5, n_jobs=-1)
svm_grid_search = GridSearchCV(svm.SVC(), param_grid=svm_param_grid, cv=5, n_jobs=-1)



# Fit models using GridSearchCV
logistic_grid_search.fit(X_train, Y_train)
xgboost_grid_search.fit(X_train, Y_train)
svm_grid_search.fit(X_train, Y_train)

# Print best hyperparameters from GridSearchCV
print("Logistic Regression Best Parameters (GridSearchCV):", logistic_grid_search.best_params_)
print("XGBoost Best Parameters (GridSearchCV):", xgboost_grid_search.best_params_)
print("SVM Best Parameters (GridSearchCV):", svm_grid_search.best_params_)

# Compare cross-validated scores of each model
logistic_cv_score = logistic_grid_search.best_score_
xgboost_cv_score = xgboost_grid_search.best_score_
svm_cv_score = svm_grid_search.best_score_

# Select the best model based on cross-validated scores
best_model = None
if logistic_cv_score >= xgboost_cv_score and logistic_cv_score >= svm_cv_score:
    best_model = logistic_grid_search.best_estimator_
elif xgboost_cv_score >= logistic_cv_score and xgboost_cv_score >= svm_cv_score:
    best_model = xgboost_grid_search.best_estimator_
else:
    best_model = svm_grid_search.best_estimator_

# Evaluate the best model on the test set
train_accuracy = best_model.score(X_train, Y_train)
print("Best Model Train Accuracy:", train_accuracy)
test_accuracy = best_model.score(X_test, Y_test)
print("Best Model Test Accuracy:", test_accuracy)
# Out:
# C:\Users\Zooby\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 52 is smaller than n_iter=100. Running 52 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\Zooby\anaconda3\lib\site-packages\xgboost\core.py:160: UserWarning: [13:05:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "probability" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\Zooby\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 80 is smaller than n_iter=100. Running 80 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Logistic Regression Best Parameters: {'solver': 'liblinear', 'penalty': 'l2', 'C': 0.1}
# ...

# %%
#cancer
input_data = (19.02,24.59,122,1076,0.09029,0.1206,0.1468,0.08271,0.1953,0.05629,0.5495,0.6636,3.055,57.65,0.003872,0.01842,0.0371,0.012,0.01964,0.003337,24.56,30.41,152.9,1623,0.1249,0.3206,0.5755,0.1956,0.3956,0.09288)
#not cancer
#input_data = (13.54,14.36,87.46,566.3,0.09779,0.08129,0.06664,0.04781,0.1885,0.05766,0.2699,0.7886,2.058,23.56,0.008462,0.0146,0.02387,0.01315,0.0198,0.0023,15.11,19.26,99.7,711.2,0.144,0.1773,0.239,0.1288,0.2977,0.07259)
#cancer
#input_data = (15.37,22.76,100.2,728.2,0.092,0.1036,0.1122,0.07483,0.1717,0.06097,0.3129,0.8413,2.075,29.44,0.009882,0.02444,0.04531,0.01763,0.02471,0.002142,16.43,25.84,107.5,830.9,0.1257,0.1997,0.2846,0.1476,0.2556,0.06828)

#convert to numpy array
input_data_as_numpy_array = np.asarray(input_data)
#reshape the numpy array as we are predicting for one instance
input_data_reshape = input_data_as_numpy_array.reshape(1,-1)

prediction = best_model.predict(input_data_reshape)
print(prediction)

if (prediction[0] == 0):
    print('The object is a cancer')
else:
    print('The object is a not cancer')
# Out:
# [1]
# The object is a not cancer

# %%
y_pred = best_model.predict(X_test)

# Calculate evaluation metrics
accuracy = accuracy_score(Y_test, y_pred)
precision = precision_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
roc_auc = roc_auc_score(Y_test, best_model.predict_proba(X_test)[:, 1])
conf_matrix = confusion_matrix(Y_test, y_pred)

# Print the results
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 0.9736842105263158
# Precision: 1.0
# Recall: 0.9285714285714286
# F1 Score: 0.962962962962963
# ROC AUC Score: 0.9828042328042328
# Confusion Matrix:
# [[72  0]
#  [ 3 39]]

# %%
# Define the XGBoost classifier
xgb_classifier = XGBClassifier()

# Define the hyperparameter distributions for RandomizedSearchCV
random_param_distributions = {
    'learning_rate': uniform(0.01, 0.2 - 0.01),
    'n_estimators': randint(50, 200),
    'max_depth': randint(3, 10),
    'min_child_weight': randint(1, 6),
    'subsample': uniform(0.5, 1 - 0.5),
    'colsample_bytree': uniform(0.5, 1 - 0.5),
}

# Perform RandomizedSearchCV
random_search = RandomizedSearchCV(
    xgb_classifier, random_param_distributions, n_iter=10, scoring='accuracy', cv=5, n_jobs=-1
)

random_search.fit(X_train, Y_train)

# Display the best parameters from RandomizedSearchCV
print("Best Parameters from RandomizedSearchCV:", random_search.best_params_)
# Out:
# Best Parameters from RandomizedSearchCV: {'colsample_bytree': 0.6481880727140984, 'learning_rate': 0.15529390719665573, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 144, 'subsample': 0.6586253156169484}

# %%
# Define the hyperparameter grid for GridSearchCV based on the results from RandomizedSearchCV
grid_param_grid = {
    'learning_rate': [random_search.best_params_['learning_rate']],
    'n_estimators': [random_search.best_params_['n_estimators']],
    'max_depth': np.arange(
        max(1, random_search.best_params_['max_depth'] - 1),
        min(15, random_search.best_params_['max_depth'] + 2),
    ),
    'min_child_weight': np.arange(
        max(1, random_search.best_params_['min_child_weight'] - 1),
        min(10, random_search.best_params_['min_child_weight'] + 2),
    ),
    'subsample': np.linspace(
        max(0.1, random_search.best_params_['subsample'] - 0.2),
        min(1, random_search.best_params_['subsample'] + 0.2),
        5,
    ),
    'colsample_bytree': np.linspace(
        max(0.1, random_search.best_params_['colsample_bytree'] - 0.2),
        min(1, random_search.best_params_['colsample_bytree'] + 0.2),
        5,
    ),
}

# Perform GridSearchCV
grid_search = GridSearchCV(
    xgb_classifier, grid_param_grid, scoring='accuracy', cv=5, n_jobs=-1
)

grid_search.fit(X_train, Y_train)

# Display the best parameters and accuracy score from GridSearchCV
print("Best Parameters from GridSearchCV:", grid_search.best_params_)
print("Best Accuracy Score from GridSearchCV:", grid_search.best_score_)

# Evaluate the final model on the test set
final_model = grid_search.best_estimator_
y_pred_test = final_model.predict(X_test)
y_pred_train = final_model.predict(X_train)
accuracy_train = accuracy_score(Y_train, y_pred_train)
accuracy_test = accuracy_score(Y_test, y_pred_test)
print("Final Model Accuracy on Test Set:", accuracy_test)
print("Final Model Accuracy on Train Set:", accuracy_train)
# Out:
# Best Parameters from GridSearchCV: {'colsample_bytree': 0.4481880727140984, 'learning_rate': 0.15529390719665573, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 144, 'subsample': 0.6586253156169484}
# Best Accuracy Score from GridSearchCV: 0.9780219780219781
# Final Model Accuracy on Test Set: 0.956140350877193
# Final Model Accuracy on Train Set: 0.9978021978021978

# %%
#cancer
#input_data = (19.02,24.59,122,1076,0.09029,0.1206,0.1468,0.08271,0.1953,0.05629,0.5495,0.6636,3.055,57.65,0.003872,0.01842,0.0371,0.012,0.01964,0.003337,24.56,30.41,152.9,1623,0.1249,0.3206,0.5755,0.1956,0.3956,0.09288)
#not cancer
input_data = (13.54,14.36,87.46,566.3,0.09779,0.08129,0.06664,0.04781,0.1885,0.05766,0.2699,0.7886,2.058,23.56,0.008462,0.0146,0.02387,0.01315,0.0198,0.0023,15.11,19.26,99.7,711.2,0.144,0.1773,0.239,0.1288,0.2977,0.07259)
#cancer
#input_data = (15.37,22.76,100.2,728.2,0.092,0.1036,0.1122,0.07483,0.1717,0.06097,0.3129,0.8413,2.075,29.44,0.009882,0.02444,0.04531,0.01763,0.02471,0.002142,16.43,25.84,107.5,830.9,0.1257,0.1997,0.2846,0.1476,0.2556,0.06828)

#convert to numpy array
input_data_as_numpy_array = np.asarray(input_data)
#reshape the numpy array as we are predicting for one instance
input_data_reshape = input_data_as_numpy_array.reshape(1,-1)

#standardizing the data
input_data_std = scaler.transform(input_data_reshape)


prediction = final_model.predict(input_data_std)
print(prediction)

if (prediction[0] == 0):
    print("Not cancer")
else:
    print("Cancer")
# Out:
# [0]
# Not cancer
# C:\Users\Zooby\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Calculate confusion matrix
cm = confusion_matrix(Y_test, y_pred_test)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', cbar=False, 
            xticklabels=['Predicted Negative', 'Predicted Positive'], 
            yticklabels=['Actual Negative', 'Actual Positive'])
plt.xlabel('Predicted labels')
plt.ylabel('Actual labels')
plt.title('Confusion Matrix')
plt.show()
